# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/Forest_Fires_Dataset.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Library/Caches/pypoetry/virtualenvs/global-wildfires-climate-GP58V2Vp-py3.14/lib/python3.14/site-packages/pandas/core/generic.py in ?(cls, axis)
#     579             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     580         except KeyError:
# --> 581             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/m1/45zjfgx53p92lc_4czzvf_b00000gn/T/ipykernel_89243/3969243486.py in ?()
# ----> 1 df.groupby("Country", "Region")
#
# ...
